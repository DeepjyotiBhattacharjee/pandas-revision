# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mrinalmayank7/datascience/main/zom.csv")
df
# Out:
#       Restaurant ID           Restaurant_Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant_Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'lon', 'lat', 'Cuisines',
#        'cost_for_two', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Price_Range', 'Rating',
#        'Rating color', 'Review', 'Votes'],
#       dtype='object')

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.describe().T
# Out:
#                 count          mean           std         min            25%  \
# Restaurant ID  9551.0  9.051128e+06  8.791521e+06   53.000000  301962.500000
# Country Code   9551.0  1.836562e+01  5.675055e+01    1.000000       1.000000
# lon            9551.0  6.412657e+01  4.146706e+01 -157.948486      77.081343
# lat            9551.0  2.585438e+01  1.100794e+01  -41.330428      28.478713
# cost_for_two   9551.0  1.199211e+03  1.612118e+04    0.000000     250.000000
# Price_Range    9551.0  1.804837e+00  9.056088e-01    1.000000       1.000000
# Rating         9551.0  2.666370e+00  1.516378e+00    0.000000       2.500000
# Votes          9551.0  1.569097e+02  4.301691e+02    0.000000       5.000000
#
#                         50%           75%           max
# Restaurant ID  6.004089e+06  1.835229e+07  1.850065e+07
# Country Code   1.000000e+00  1.000000e+00  2.160000e+02
# lon            7.719196e+01  7.728201e+01  1.748321e+02
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant_Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# lon                     0
# lat                     0
# Cuisines                9
# cost_for_two            0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price_Range             0
# Rating                  0
# Rating color            0
# Review                  0
# Votes                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[['Restaurant ID','Restaurant_Name','cost_for_two']]
# Out:
#       Restaurant ID           Restaurant_Name  cost_for_two
# 0           6317637          Le Petit Souffle          1100
# 1           6304287          Izakaya Kikufuji          1200
# 2           6300002    Heat - Edsa Shangri-La          4000
# 3           6318506                      Ooma          1500
# 4           6314302               Sambo Kojin          1500
# ...             ...                       ...           ...
# 9546        5915730               Naml۱ Gurme            80
# 9547        5908749              Ceviz A��ac۱           105
# 9548        5915807                     Huqqa           170
# 9549        5916112               A���k Kahve           120
# 9550        5927402  Walter's Coffee Roastery            55
#
# [9551 rows x 3 columns]

# %%
 df = pd.read_excel("airline.xls")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py:141, in import_optional_dependency(name, extra, errors, min_version)
#     140 try:
# --> 141     module = importlib.import_module(name)
#     142 except ImportError:
#
# File ~/anaconda3/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1142, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# !pip install xlrd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 1.7 MB/s eta 0:00:00a 0:00:01
# ...

# %%
 df = pd.read_excel("airline.xls")

# %%
df
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
 df = pd.read_excel("airline.xls",sheet_name='Sheet2')

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df4 = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")
df4
# Out:
# [       Season   Age                                     Tm  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
# ...

# %%
type(df4)
# Out:
# list

# %%
len(df4)
# Out:
# 7

# %%
# we have 7 tables in this list

# %%
df4[0]
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
df4[0].to_csv('test.csv',index=False)

# %%
# !ls
# Out:
# airline.xls    pandas_1.ipynb test.csv

# %%
titanic_df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = '''
{
"name":"Deep",
"phone":10000,
"companies":["Capgemini","Boston Harbor Consulting","Knacksystems","Accenture"]
}
'''

# %%
import json

# %%
s1 = json.loads(s)
s1
# Out:
# {'name': 'Deep',
#  'phone': 10000,
#  'companies': ['Capgemini',
#   'Boston Harbor Consulting',
#   'Knacksystems',
#   'Accenture']}

# %%
pd.DataFrame(s1)
# Out:
#    name  phone                 companies
# 0  Deep  10000                 Capgemini
# 1  Deep  10000  Boston Harbor Consulting
# 2  Deep  10000              Knacksystems
# 3  Deep  10000                 Accenture

# %%
pd.DataFrame(s1,columns=['companies'])
# Out:
#                   companies
# 0                 Capgemini
# 1  Boston Harbor Consulting
# 2              Knacksystems
# 3                 Accenture

# %%
import requests
res=requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")
res
# Out:
# <Response [200]>

# %%
js = res.json()
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57731',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57731/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57731/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57731/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57731',
#   'id': 2168136869,
#   'node_id': 'I_kwDOAA0YD86BOySl',
#   'number': 57731,
#   'title': 'ENH: interleave_columns function',
#   'user': {'login': 'raybellwaves',
#    'id': 17162724,
#    'node_id': 'MDQ6VXNlcjE3MTYyNzI0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17162724?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/raybellwaves',
#    'html_url': 'https://github.com/raybellwaves',
# ...

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57731',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57731/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57731/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57731/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/issues/57731',
#  'id': 2168136869,
#  'node_id': 'I_kwDOAA0YD86BOySl',
#  'number': 57731,
#  'title': 'ENH: interleave_columns function',
#  'user': {'login': 'raybellwaves',
#   'id': 17162724,
#   'node_id': 'MDQ6VXNlcjE3MTYyNzI0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/17162724?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/raybellwaves',
#   'html_url': 'https://github.com/raybellwaves',
#   'followers_url': 'https://api.github.com/users/raybellwaves/followers',
# ...

# %%
js[0]['title']
# Out:
# 'ENH: interleave_columns function'

# %%
js[0]['url']
# Out:
# 'https://api.github.com/repos/pandas-dev/pandas/issues/57731'

# %%
for i in js:
    print(i['url'])
# Out:
# https://api.github.com/repos/pandas-dev/pandas/issues/57731
# https://api.github.com/repos/pandas-dev/pandas/issues/57730
# https://api.github.com/repos/pandas-dev/pandas/issues/57725
# https://api.github.com/repos/pandas-dev/pandas/issues/57724
# https://api.github.com/repos/pandas-dev/pandas/issues/57723
# https://api.github.com/repos/pandas-dev/pandas/issues/57722
# https://api.github.com/repos/pandas-dev/pandas/issues/57717
# https://api.github.com/repos/pandas-dev/pandas/issues/57716
# https://api.github.com/repos/pandas-dev/pandas/issues/57713
# https://api.github.com/repos/pandas-dev/pandas/issues/57712
# https://api.github.com/repos/pandas-dev/pandas/issues/57710
# https://api.github.com/repos/pandas-dev/pandas/issues/57709
# https://api.github.com/repos/pandas-dev/pandas/issues/57706
# https://api.github.com/repos/pandas-dev/pandas/issues/57705
# https://api.github.com/repos/pandas-dev/pandas/issues/57704
# https://api.github.com/repos/pandas-dev/pandas/issues/57703
# ...

# %%
l = []
for i in range(len(js)):
    l.append(js[i]['url'])

# %%
l
# Out:
# ['https://api.github.com/repos/pandas-dev/pandas/issues/57731',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57730',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57725',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57724',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57723',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57722',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57717',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57716',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57713',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57712',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57710',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57709',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57706',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57705',
#  'https://api.github.com/repos/pandas-dev/pandas/issues/57704',
# ...

# %%
len(l)
# Out:
# 30

# %%
pd.DataFrame(js,columns=['url','title'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df5 = pd.DataFrame(js)
df5.to_csv("json_dump.csv")

# %%
js[0]['user']
# Out:
# {'login': 'raybellwaves',
#  'id': 17162724,
#  'node_id': 'MDQ6VXNlcjE3MTYyNzI0',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/17162724?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/raybellwaves',
#  'html_url': 'https://github.com/raybellwaves',
#  'followers_url': 'https://api.github.com/users/raybellwaves/followers',
#  'following_url': 'https://api.github.com/users/raybellwaves/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/raybellwaves/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/raybellwaves/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/raybellwaves/subscriptions',
#  'organizations_url': 'https://api.github.com/users/raybellwaves/orgs',
#  'repos_url': 'https://api.github.com/users/raybellwaves/repos',
#  'events_url': 'https://api.github.com/users/raybellwaves/events{/privacy}',
# ...

# %%
user_list = []

for i in js:
    user_list.append(i['user'])

# %%
print(user_list)
# Out:
# [{'login': 'raybellwaves', 'id': 17162724, 'node_id': 'MDQ6VXNlcjE3MTYyNzI0', 'avatar_url': 'https://avatars.githubusercontent.com/u/17162724?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/raybellwaves', 'html_url': 'https://github.com/raybellwaves', 'followers_url': 'https://api.github.com/users/raybellwaves/followers', 'following_url': 'https://api.github.com/users/raybellwaves/following{/other_user}', 'gists_url': 'https://api.github.com/users/raybellwaves/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/raybellwaves/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/raybellwaves/subscriptions', 'organizations_url': 'https://api.github.com/users/raybellwaves/orgs', 'repos_url': 'https://api.github.com/users/raybellwaves/repos', 'events_url': 'https://api.github.com/users/raybellwaves/events{/privacy}', 'received_events_url': 'https://api.github.com/users/raybellwaves/received_events', 'type': 'User', 'site_admin': False}, {'log
# ...

# %%
print(len(i))
# Out:
# 30

# %%
pd.DataFrame(user_list)
# Out:
#                  login         id               node_id  \
# 0         raybellwaves   17162724  MDQ6VXNlcjE3MTYyNzI0
# 1              WillAyd     609873  MDQ6VXNlcjYwOTg3Mw==
# 2   pre-commit-ci[bot]   66853113  MDM6Qm90NjY4NTMxMTM=
# 3              sls-mdr   50274097  MDQ6VXNlcjUwMjc0MDk3
# 4               Dr-Irv   15113894  MDQ6VXNlcjE1MTEzODk0
# 5                  jxu    7989982  MDQ6VXNlcjc5ODk5ODI=
# 6               Rand-0   60578707  MDQ6VXNlcjYwNTc4NzA3
# 7           kanhapatil  101468170          U_kgDOBgxICg
# 8               NoelMT   58369280  MDQ6VXNlcjU4MzY5Mjgw
# 9         DeaMariaLeon   11835246  MDQ6VXNlcjExODM1MjQ2
# 10           mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 11     thetestspecimen   40262729  MDQ6VXNlcjQwMjYyNzI5
# 12          rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 13             WillAyd     609873  MDQ6VXNlcjYwOTg3Mw==
# 14             WillAyd     609873  MDQ6VXNlcjYwOTg3Mw==
# 15           MarcusJak   78412619  MDQ6VXNlcjc4NDEyNjE5
# ...

# %%
## Another approach

df = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data = pd.DataFrame.from_records(df['user'])
data
# Out:
#                  login         id               node_id  \
# 0                s1099   46890315  MDQ6VXNlcjQ2ODkwMzE1
# 1         raybellwaves   17162724  MDQ6VXNlcjE3MTYyNzI0
# 2              WillAyd     609873  MDQ6VXNlcjYwOTg3Mw==
# 3   pre-commit-ci[bot]   66853113  MDM6Qm90NjY4NTMxMTM=
# 4              sls-mdr   50274097  MDQ6VXNlcjUwMjc0MDk3
# 5               Dr-Irv   15113894  MDQ6VXNlcjE1MTEzODk0
# 6                  jxu    7989982  MDQ6VXNlcjc5ODk5ODI=
# 7               Rand-0   60578707  MDQ6VXNlcjYwNTc4NzA3
# 8           kanhapatil  101468170          U_kgDOBgxICg
# 9               NoelMT   58369280  MDQ6VXNlcjU4MzY5Mjgw
# 10        DeaMariaLeon   11835246  MDQ6VXNlcjExODM1MjQ2
# 11           mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 12     thetestspecimen   40262729  MDQ6VXNlcjQwMjYyNzI5
# 13          rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 14             WillAyd     609873  MDQ6VXNlcjYwOTg3Mw==
# 15             WillAyd     609873  MDQ6VXNlcjYwOTg3Mw==
# ...
