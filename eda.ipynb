# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 229          230         0       3  ...  25.4667   NaN         S
#
# [1 rows x 12 columns]

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 269          270         1       1  ...  135.6333   C99         S
# 662          663         0       1  ...   25.5875   E58         S
# 608          609         1       2  ...   41.5792   NaN         C
# 611          612         0       3  ...    7.0500   NaN         S
# 80            81         0       3  ...    9.0000   NaN         S
#
# [5 rows x 12 columns]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe().T
# Out:
#              count        mean         std  ...       50%    75%       max
# PassengerId  891.0  446.000000  257.353842  ...  446.0000  668.5  891.0000
# Survived     891.0    0.383838    0.486592  ...    0.0000    1.0    1.0000
# Pclass       891.0    2.308642    0.836071  ...    3.0000    3.0    3.0000
# Age          714.0   29.699118   14.526497  ...   28.0000   38.0   80.0000
# SibSp        891.0    0.523008    1.102743  ...    0.0000    1.0    8.0000
# Parch        891.0    0.381594    0.806057  ...    0.0000    0.0    6.0000
# Fare         891.0   32.204208   49.693429  ...   14.4542   31.0  512.3292
#
# [7 rows x 8 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.corr()
# Out:
# /var/folders/31/h661wdqj5pzb01symws5rm_40000gn/T/ipykernel_63709/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              PassengerId  Survived    Pclass  ...     SibSp     Parch      Fare
# PassengerId     1.000000 -0.005007 -0.035144  ... -0.057527 -0.001652  0.012658
# Survived       -0.005007  1.000000 -0.338481  ... -0.035322  0.081629  0.257307
# Pclass         -0.035144 -0.338481  1.000000  ...  0.083081  0.018443 -0.549500
# Age             0.036847 -0.077221 -0.369226  ... -0.308247 -0.189119  0.096067
# SibSp          -0.057527 -0.035322  0.083081  ...  1.000000  0.414838  0.159651
# Parch          -0.001652  0.081629  0.018443  ...  0.414838  1.000000  0.216225
# Fare            0.012658  0.257307 -0.549500  ...  0.159651  0.216225  1.000000
#
# [7 rows x 7 columns]

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True)
# Out:
# /var/folders/31/h661wdqj5pzb01symws5rm_40000gn/T/ipykernel_63709/1950383679.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
# types of analysis :
    # univariate analysis
    # bivariate analysis
    # multivariate analysis

# %% [markdown]
# # univariate analysis

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# categorical variable and numerical variable

# %%
categorical_cols = df.dtypes[df.dtypes == 'object'].index
categorical_cols
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
numerical_cols = df.dtypes[df.dtypes != 'object'].index
numerical_cols
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
df[categorical_cols]
# Out:
#                                                   Name     Sex  ... Cabin Embarked
# 0                              Braund, Mr. Owen Harris    male  ...   NaN        S
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  ...   C85        C
# 2                               Heikkinen, Miss. Laina  female  ...   NaN        S
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  ...  C123        S
# 4                             Allen, Mr. William Henry    male  ...   NaN        S
# ..                                                 ...     ...  ...   ...      ...
# 886                              Montvila, Rev. Juozas    male  ...   NaN        S
# 887                       Graham, Miss. Margaret Edith  female  ...   B42        S
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  ...   NaN        S
# 889                              Behr, Mr. Karl Howell    male  ...  C148        C
# ...

# %%
df[numerical_cols]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %% [markdown]
# # Categorical columns

# %% [markdown]
# ### count plot

# %%
sns.countplot(data=df,x='Embarked' )
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
# Most of the people onboarded from S(Southampton), and the least people onboarded from Q (Queenstown)

# %%
sns.countplot(data=df,x='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
# There were more males than females on the cruise

# %%
sns.countplot(data=df,x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# Most people were in Pclass 3 followed by Pclass1 than Pclass2

# %% [markdown]
# ### pie chart

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Sex'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Pclass'>

# %% [markdown]
# # Numerical Columns

# %% [markdown]
# ### Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Age'],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
# histplot
sns.distplot(df['Age'])
# Out:
# /var/folders/31/h661wdqj5pzb01symws5rm_40000gn/T/ipykernel_63709/50911776.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# the probability of having people on the cruise with age between 20 to 40 was more

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
min(df['Age'])
# Out:
# 0.42

# %%
max(df['Age'])
# Out:
# 80.0

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
df['Age'].skew()*100
# Out:
# 38.910778230082705

# %%
# 38.9 percent of the data is skewed

# %%
1-df['Age'].skew()
# Out:
# 0.6108922176991729

# %%
# 61 percent of the data is not skewed

# %% [markdown]
# # bivariate analysis

# %% [markdown]
# 1. categorical var,
# 2. numerical var.
#
# - types of analyses :
# 1. categorical vs categorical
# 2. numerical vs numerical
# 3. categorical vs numerical

# %% [markdown]
# # multivariate analysis
#
# ### here more than 2 columns will be involved

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
flight = sns.load_dataset('flights')
iris = sns.load_dataset('iris')

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### scatter plot (when both x and y are numerical columns)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip') # this is a bivariate analysis
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# as my bill increases, tip also increases

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex') # multivariate analysis
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex',style='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex',style='smoker',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### bar plot (when x is numerical and y is categorical column)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
sns.barplot(data=df,x='Pclass',y='Age') # bivariate analysis
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(data=df,x='Pclass',y='Age',hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ### box plot (when x is numerical and y is categorical column)

# %%
sns.boxplot(data=df,x='Sex',y='Age')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(data=df,x='Sex',y='Age',hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
df[df['Survived']==0]['Age'].min() # the min age of a person that did not survive was 1
# Out:
# 1.0

# %%
df[df['Survived']==0]['Age'].max() # the max age of a person that did not survive was 74
# Out:
# 74.0

# %%
df[df['Survived']==1]['Age'].max() # the max age of a person that survived was 80
# Out:
# 80.0

# %%
df[df['Survived']==1]['Age'].min() # the min age of a person that survived was 0.42
# Out:
# 0.42

# %%
sns.distplot(df[df['Survived']==0]['Age'])
# Out:
# /var/folders/31/h661wdqj5pzb01symws5rm_40000gn/T/ipykernel_63709/529285220.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df[df['Survived']==0]['Age'],hist=False)
# Out:
# /var/folders/31/h661wdqj5pzb01symws5rm_40000gn/T/ipykernel_63709/1451709491.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'],hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df[df['Survived']==1]['Age'])
# Out:
# /var/folders/31/h661wdqj5pzb01symws5rm_40000gn/T/ipykernel_63709/3711782503.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==1]['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df[df['Survived']==1]['Age'],hist=False)
# Out:
# /var/folders/31/h661wdqj5pzb01symws5rm_40000gn/T/ipykernel_63709/225183552.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==1]['Age'],hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df[df['Survived']==1]['Age'],hist=False)
sns.distplot(df[df['Survived']==0]['Age'],hist=False)
# Out:
# /var/folders/31/h661wdqj5pzb01symws5rm_40000gn/T/ipykernel_63709/4185559464.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==1]['Age'],hist=False)
# /var/folders/31/h661wdqj5pzb01symws5rm_40000gn/T/ipykernel_63709/4185559464.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ### heatmap (both x and y are categorical variables)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
pd.crosstab(df['Pclass'],df['Survived']) # used to combine two classes
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']),annot=True)
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(data=iris)

# %%
sns.pairplot(data=iris,hue='species')

# %% [markdown]
# ### lineplot (both x and y are numerical)

# %%
sns.lineplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ### use lineplot mostly with time related data

# %%
flight_new = flight.groupby('year').sum().reset_index()
flight_new
# Out:
# /var/folders/31/h661wdqj5pzb01symws5rm_40000gn/T/ipykernel_63709/3273199004.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   flight_new = flight.groupby('year').sum().reset_index()
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.lineplot(data=flight_new,x='year',y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flight,x='month',y='passengers')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flight.pivot_table(values='passengers',index='month')
# Out:
#        passengers
# month
# Jan    241.750000
# Feb    235.000000
# Mar    270.166667
# Apr    267.083333
# May    271.833333
# Jun    311.666667
# Jul    351.333333
# Aug    351.083333
# Sep    302.416667
# Oct    266.583333
# Nov    232.833333
# Dec    261.833333

# %%
flight.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
flight.groupby('month').sum()
# Out:
#         year  passengers
# month
# Jan    23454        2901
# Feb    23454        2820
# Mar    23454        3242
# Apr    23454        3205
# May    23454        3262
# Jun    23454        3740
# Jul    23454        4216
# Aug    23454        4213
# Sep    23454        3629
# Oct    23454        3199
# Nov    23454        2794
# Dec    23454        3142

# %%
plt.figure(figsize=(15,15))
sns.heatmap(flight.pivot_table(values='passengers',index='month',columns='year'),annot=True)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# # Pandas profiling

# %%
# !pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df,title="Pandas profiling report")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile.to_file('your_report.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !ls
# Out:
# airline.xls      json_dump.csv    pandas_1.ipynb   test.h5
# eda.ipynb        my_pickle        test.csv         your_report.html
